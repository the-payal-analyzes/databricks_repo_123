# %% [markdown]
# ![image not avaialble](https://fplogoimages.withfloats.com/actual/68009c3a43430aff8a30419d.png)
# # ALL About Markdown

# %% [markdown]
# # header 1
# ## header 2
# ### header 3

# %% [markdown]
# **Spark**
# `for i in range`

# %% [markdown]
# - spark
# - databricks

# %% [markdown]
# > spark

# %% [markdown]
# # Heading 1
# ## Heading 2
# ### Heading 3
#
# **Bold text** and *italic text*
# and ~~strikethrough~~ and `inline code`
#
# ---  ← horizontal rule
#
# ## Lists
# - Item one
# - Item two
#   - Nested item
#
# 1. First
# 2. Second
#
# ## Code Block
# ```python
# df = spark.read.parquet("/mnt/data")
# df.show()
# ```
#
# ## Blockquote
# > This is an important note.
#
# ## Table
# | Col A | Col B |
# |-------|-------|
# | val 1 | val 2 |
#
# ## Link & Image
# [Databricks Docs](https://docs.databricks.com)
# ![Alt text](https://url-to-image.png)
