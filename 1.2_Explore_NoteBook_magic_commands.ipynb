# %% [markdown]
# # Welcome To IZ Databricks Learning
# we are learning all about NoteBooks with Magical Commands

# %% [markdown]
# ### Important Magic commands
# - %md : Markdown
# - %python : python code cell
# - %sql : run sql quries
# - %scala - scala code cell
# - %sh - shell commands
# - %fs - intract with DBFS (databricks file system )
# - %pip - install packages
# - %run - call another notebook

# %% [markdown]
# Running SQL quries

# %%
# %sql
select current_timestamp,current_user

# %%
# %sql
show databases;

# %% [markdown]
# Run Shell commands

# %%
# %sh
ls -l
cp main.py main1.py

# %%
ls -l

# %% [markdown]
# how to run another Notebook

# %%
# %run "/Workspace/Users/inceptezwd33we44@gmail.com/iz_we48_databricks_repo/testNotebook"

# %%
# %run "./testNotebook"
